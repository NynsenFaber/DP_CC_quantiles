# %%
# autoreload modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Create Dataset

# %%
import numpy as np

N = 500_000
DATASET = {}

# generate data from beta distribution
set_of_parameters = [(0.5, 0.5), (1, 3), (2, 2), (2, 5)]  # from Figure 1 https://arxiv.org/pdf/2302.06943
for parameters in set_of_parameters:
    data = np.random.beta(*parameters, N)
    data = np.sort(data)
    DATASET[f'Beta_{parameters[0]}_{parameters[1]}'] = {"data": data}

# generate data from mixture of beta distributions
number_of_centers = [np.random.uniform(0, 10 ** 3, 10),
                     np.random.uniform(0, 10 ** 3, 100),
                     np.random.uniform(0, 10 ** 3, 1000)]
n_per_center = [[N // len(c)] * len(c) + [N % len(c)] for c in number_of_centers]
for centers, n_per_c in zip(number_of_centers, n_per_center):
    data = np.concatenate([loc + np.random.beta(2, 5, size=n) for loc, n in zip(centers, n_per_c)])
    data = np.sort(data)
    DATASET[f'{len(centers)}_Mixture_Beta_2_5'] = {"data": data}

# %% [markdown]
# # Post Process to get the Bounds and minimum gap

# %%
# get a valid minimum gap by scaling
MIN_G = 1
for key, data in DATASET.items():
    array = data["data"]
    g = np.min(np.diff(array))
    scale = MIN_G / g
    DATASET[key]["data"] = array * scale  # Update the scaled array back into the dataset
    new_gap = np.min(np.diff(DATASET[key]["data"]))

# %%
BOUND = (0, 2 ** 64 - 1)
# check if the bound is valid
for key, data in DATASET.items():
    array = data["data"]
    assert np.all(array >= BOUND[0]) and np.all(array <= BOUND[1]), f"Invalid bounds for {key}"
    print(f"Valid bounds for {key}: {BOUND}")
# Out:
# Valid bounds for Beta_0.5_0.5: (0, 18446744073709551615)
# Valid bounds for Beta_1_3: (0, 18446744073709551615)
# Valid bounds for Beta_2_2: (0, 18446744073709551615)
# Valid bounds for Beta_2_5: (0, 18446744073709551615)
# Valid bounds for 10_Mixture_Beta_2_5: (0, 18446744073709551615)
# Valid bounds for 100_Mixture_Beta_2_5: (0, 18446744073709551615)
# Valid bounds for 1000_Mixture_Beta_2_5: (0, 18446744073709551615)

# %% [markdown]
# # Set Privacy Budgets

# %% [markdown]
# We propose $\varepsilon, \delta$ that are used in SliceQuantiles, and compute the highest $\rho$ for zCDP that implies the same $\varepsilon, \delta$.

# %%
from scipy.optimize import root_scalar


def get_max_rho(eps, delta):
    """
    Get the maximum rho for a given epsilon and delta.
    """
    epsilon_func = lambda rho: rho + np.sqrt(4 * rho * np.log(np.sqrt(np.pi * rho) / delta)) - eps

    # Use a numerical solver to find the root of epsilon_func
    result = root_scalar(epsilon_func, bracket=[1e-10, 10], method='brentq')

    if result.converged:
        return result.root
    else:
        raise ValueError("Failed to find a valid rho for the given epsilon and delta.")


eps = 1.
delta = 1e-10
rho = get_max_rho(eps, delta)
print("For eps = {}, delta = {}, max rho = {}".format(eps, delta, rho))
# Out:
# For eps = 1.0, delta = 1e-10, max rho = 0.011436474747206712

# %% [markdown]
# # Hyperparameters

# %%
EPS = 1.
DELTA = 1e-16
RHO = get_max_rho(EPS, DELTA)
M_LIST = range(10, 100, 10)
# Q_LIST = [np.linspace(0, 1, num=m + 2)[1:-1] for m in M_LIST]
Q_LIST = [np.array([(1 / 4) + (i / (2*(m + 1))) for i in range(1, m + 1)]) for m in M_LIST]
SWAP = False
NUM_EXPERIMENTS = 50

# %%
records = []  # to store the records of each experiment

# %%
import math


def get_statistics(X: np.ndarray, quantiles: np.ndarray, estimates: np.ndarray) -> float:
    """
    Compute the maximum rank error and the mean absolute rank error between the true quantiles and the estimated quantiles.
    :param X: data set
    :param quantiles: a list of quantiles (values in [0, 1])
    :param estimates: a list of estimated qth-quantiles (values in X)
    :return: a dictionary with the maximum rank error and the mean absolute rank error
    """
    # sort the data
    X = np.sort(X)
    n = len(X)

    # for each result, get the position of the closest element in the sorted array
    positions = np.searchsorted(X, estimates)
    true_positions = [math.floor(q * n) for q in quantiles]

    # compute the normalized rank error
    rank_errors = np.abs(positions - true_positions)

    # get statistics
    max_rank_error = np.max(rank_errors)
    mean_rank_error = np.mean(rank_errors)
    output = {
        'max_error':  max_rank_error,
        'mean_error': mean_rank_error  # Kaplan et al. uses this
    }
    return output

# %% [markdown]
# # Run SliceQuantiles

# %% [markdown]
# ## Check correcteness of the privacy parameters

# %%
from our_mechanism import SliceQuantile

# Check if the privacy parameters are valid for any values of m
for m, q_list in zip(M_LIST, Q_LIST):
    mechanism = SliceQuantile(bound=BOUND, n=N, m=m, eps=EPS, split=0.5, swap=SWAP, g=MIN_G)
    if not mechanism.is_delta_approximate_DP(delta=DELTA, q_list=q_list):
        raise ValueError(f"At m={m} failed to find a valid delta approximate DP.")
print("All privacy parameters are valid for the given m values.")
# Out:
# All privacy parameters are valid for the given m values.

# %% [markdown]
# ## Run the experiments

# %%
from tqdm import tqdm

for key, data in tqdm(DATASET.items(), total=len(DATASET), desc="Datasets"):
    X = data["data"]
    for _, (m, q_list) in enumerate(zip(M_LIST, Q_LIST)):
        mechanism = SliceQuantile(bound=BOUND, n=N, m=m, eps=EPS, split=0.5, swap=SWAP, g=MIN_G)
        for _ in range(NUM_EXPERIMENTS):
            estimates = mechanism.approximate_mechanism(X, q_list=q_list, delta=DELTA, verbose=True)
            statistics = get_statistics(X, quantiles=q_list, estimates=estimates)
            records.append({
                "dataset":    key,
                "m":          m,
                "max_error":  statistics["max_error"],
                "mean_error": statistics["mean_error"],
                "Algorithm":  "SliceQuantile",
            })
# Out:
# Datasets: 100%|██████████| 7/7 [01:59<00:00, 17.09s/it]

# %% [markdown]
# # Run Approximate Quantiles, from Kaplan et al.

# %%
from DP_AQ import approximate_quantiles_algo

for key, data in tqdm(DATASET.items(), total=len(DATASET), desc="Datasets"):
    X = data["data"]
    for _, (m, q_list) in enumerate(zip(M_LIST, Q_LIST)):
        for _ in range(NUM_EXPERIMENTS):
            estimates = approximate_quantiles_algo(array=X, quantiles=q_list, bounds=BOUND,
                                                   epsilon=RHO, swap=SWAP, cdp=True)
            statistics = get_statistics(X, quantiles=q_list, estimates=estimates)
            records.append({
                "dataset":    key,
                "m":          m,
                "max_error":  statistics["max_error"],
                "mean_error": statistics["mean_error"],
                "Algorithm":  "Approximate Quantiles",
            })
# Out:
# Datasets: 100%|██████████| 7/7 [07:02<00:00, 60.43s/it]

# %% [markdown]
# # Run Histogram Approach

# %%
if SWAP:
    sensitivity = 2
else:
    sensitivity = 1
for key, data in tqdm(DATASET.items(), total=len(DATASET), desc="Datasets"):
    X = data["data"]
    # # Use auto binning
    # bin_edges = np.histogram_bin_edges(X, bins="auto")
    # hist, edges = np.histogram(X, bins=bin_edges)
    # uniform binning
    hist, edges = np.histogram(X, bins=200)
    bin_widths = np.diff(edges)  # Precompute bin widths for interpolation
    for m, q_list in zip(M_LIST, Q_LIST):
        for _ in range(NUM_EXPERIMENTS):
            # Add noise to the histogram for differential privacy
            noisy_hist = hist + np.random.normal(0, np.sqrt(sensitivity / (2 * RHO)), len(hist))
            # Precompute cumulative sums for rank calculation
            cumulative_counts = np.cumsum(noisy_hist)
            estimates = []
            for q in q_list:
                rank = math.floor(q * len(X))
                for i, cum_sum in enumerate(cumulative_counts):
                    if cum_sum >= rank:
                        # interpolate
                        high_bound = edges[i + 1]
                        low_bound = edges[i]
                        diff = cum_sum - rank
                        h = noisy_hist[i]
                        estimate = low_bound + ((high_bound - low_bound) / h) * diff
                        estimates.append(estimate)
                        break
                    if i == len(cumulative_counts) - 1:
                        estimates.append(edges[i + 1])

            statistics = get_statistics(X, quantiles=q_list, estimates=estimates)
            records.append({
                "dataset":    key,
                "m":          m,
                "max_error":  statistics["max_error"],
                "mean_error": statistics["mean_error"],
                "Algorithm":  "Gaussian Histogram",
            })  # 'auto' selects
# Out:
# Datasets: 100%|██████████| 7/7 [00:02<00:00,  2.50it/s]

# %%
# Remove all dictionaries in `records` where "Algorithm" is "Gaussian Histogram"
records = [record for record in records if record["Algorithm"] != "Gaussian Histogram"]

# Check the updated records
records
# Out:
# [{'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(10.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(13.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(12.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(9.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(13.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(15.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(12.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(17.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(19),
#   'mean_error': np.float64(9.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(11.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(13.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(9.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(8.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(10.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(13.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(13.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(14.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(16.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(12.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(13.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(18),
#   'mean_error': np.float64(12.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(10.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(22),
#   'mean_error': np.float64(10.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(8.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(15.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(12.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(12.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(10.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(16.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(13.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(11.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(10.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(12.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(22),
#   'mean_error': np.float64(11.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(8.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(16.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(13.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(18),
#   'mean_error': np.float64(8.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(10.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(20),
#   'mean_error': np.float64(9.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(13.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(9.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(16),
#   'mean_error': np.float64(9.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(15.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(16.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(14.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(19),
#   'mean_error': np.float64(11.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(9.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(13),
#   'mean_error': np.float64(8.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 10,
#   'max_error': np.int64(18),
#   'mean_error': np.float64(9.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(9.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(10.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(9.05),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(7.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(10.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(8.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(10.15),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(9.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(11.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(6.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(10.25),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(14.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(9.25),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(11.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(10.85),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(7.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(9.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(22),
#   'mean_error': np.float64(7.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(23),
#   'mean_error': np.float64(9.05),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(11.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(8.25),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(7.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(8.45),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(11.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(59),
#   'mean_error': np.float64(10.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(10.05),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(12.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(8.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(12.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(41),
#   'mean_error': np.float64(14.55),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(11.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(7.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(9.25),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(20),
#   'mean_error': np.float64(8.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(7.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(11.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(9.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(7.75),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(19),
#   'mean_error': np.float64(7.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(8.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(9.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(14),
#   'mean_error': np.float64(5.75),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(12.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(8.75),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(10.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(23),
#   'mean_error': np.float64(8.75),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(11.05),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(10.55),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(11.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 20,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(9.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(7.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(8.566666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(22),
#   'mean_error': np.float64(7.633333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(9.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(9.266666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(6.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(8.133333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(7.433333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(9.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(7.766666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(10.666666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(22),
#   'mean_error': np.float64(6.966666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(8.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(21),
#   'mean_error': np.float64(7.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(9.266666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(20),
#   'mean_error': np.float64(7.233333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(8.633333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(9.166666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(8.066666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(9.166666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(9.733333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(16),
#   'mean_error': np.float64(5.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(57),
#   'mean_error': np.float64(9.033333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(9.266666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(7.833333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(8.566666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(5.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(10.133333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(10.766666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(8.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(9.966666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(62),
#   'mean_error': np.float64(8.833333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(8.433333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(7.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(64),
#   'mean_error': np.float64(8.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(11.033333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(22),
#   'mean_error': np.float64(7.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(9.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(64),
#   'mean_error': np.float64(10.033333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(10.833333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(19),
#   'mean_error': np.float64(6.866666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(11.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(8.466666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(10.133333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(8.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(7.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(9.733333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(8.066666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(8.333333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 30,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(10.433333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(13.25),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(14.275),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(13.125),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(11.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(12.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(14.075),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(10.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(9.725),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(45),
#   'mean_error': np.float64(14.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(14.525),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(11.725),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(13.925),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(11.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(13.675),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(11.475),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(57),
#   'mean_error': np.float64(13.625),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(45),
#   'mean_error': np.float64(13.825),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(12.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(11.475),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(54),
#   'mean_error': np.float64(12.05),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(14.625),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(11.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(13.175),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(14.375),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(13.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(15.175),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(12.325),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(15.775),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(13.075),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(15.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(11.15),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(10.875),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(11.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(15.575),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(10.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(45),
#   'mean_error': np.float64(12.475),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(45),
#   'mean_error': np.float64(13.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(14.25),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(13.175),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(11.575),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(11.225),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(12.675),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(60),
#   'mean_error': np.float64(13.325),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(52),
#   'mean_error': np.float64(14.45),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(12.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(41),
#   'mean_error': np.float64(13.275),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(13.725),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(65),
#   'mean_error': np.float64(11.975),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(11.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 40,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(12.875),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(9.38),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(9.22),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(10.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(11.38),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(62),
#   'mean_error': np.float64(12.38),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(8.92),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(52),
#   'mean_error': np.float64(10.02),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(8.94),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(63),
#   'mean_error': np.float64(11.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(10.02),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(9.12),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(9.34),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(9.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(10.12),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(12.02),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(45),
#   'mean_error': np.float64(9.72),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(55),
#   'mean_error': np.float64(11.02),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(10.28),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(9.68),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(8.14),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(75),
#   'mean_error': np.float64(10.48),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(10.06),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(9.22),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(9.86),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(9.74),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(9.44),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(10.58),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(11.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(11.02),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(10.44),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(59),
#   'mean_error': np.float64(9.76),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(12.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(9.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(29),
#   'mean_error': np.float64(9.98),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(10.86),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(9.74),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(11.04),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(9.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(10.24),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(8.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(8.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(12.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(10.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(45),
#   'mean_error': np.float64(10.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(72),
#   'mean_error': np.float64(11.42),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(61),
#   'mean_error': np.float64(9.96),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(9.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(9.02),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(10.56),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 50,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(9.58),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(10.233333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(10.45),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(11.666666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(10.566666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(9.966666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(10.416666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(8.283333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(8.633333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(8.066666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(11.533333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(11.783333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(12.366666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(10.466666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(8.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(52),
#   'mean_error': np.float64(10.05),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(10.433333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(10.833333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(10.816666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(87),
#   'mean_error': np.float64(10.716666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(10.233333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(11.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(8.516666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(9.316666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(10.933333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(10.483333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(9.883333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(10.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(9.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(10.183333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(10.15),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(10.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(60),
#   'mean_error': np.float64(10.666666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(12.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(13.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(12.533333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(9.466666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(9.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(9.783333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(9.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(65),
#   'mean_error': np.float64(10.85),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(41),
#   'mean_error': np.float64(9.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(9.833333333333334),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(10.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(9.733333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(67),
#   'mean_error': np.float64(10.033333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(9.283333333333333),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(10.316666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(10.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(11.716666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 60,
#   'max_error': np.int64(45),
#   'mean_error': np.float64(10.716666666666667),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(56),
#   'mean_error': np.float64(17.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(16.357142857142858),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(54),
#   'mean_error': np.float64(15.17142857142857),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(63),
#   'mean_error': np.float64(18.785714285714285),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(83),
#   'mean_error': np.float64(18.714285714285715),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(54),
#   'mean_error': np.float64(17.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(54),
#   'mean_error': np.float64(17.742857142857144),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(57),
#   'mean_error': np.float64(16.728571428571428),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(70),
#   'mean_error': np.float64(16.82857142857143),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(16.942857142857143),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(16.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(69),
#   'mean_error': np.float64(18.542857142857144),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(84),
#   'mean_error': np.float64(18.685714285714287),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(63),
#   'mean_error': np.float64(17.814285714285713),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(17.414285714285715),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(41),
#   'mean_error': np.float64(18.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(65),
#   'mean_error': np.float64(17.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(61),
#   'mean_error': np.float64(18.642857142857142),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(66),
#   'mean_error': np.float64(19.642857142857142),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(64),
#   'mean_error': np.float64(19.12857142857143),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(67),
#   'mean_error': np.float64(18.085714285714285),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(54),
#   'mean_error': np.float64(17.071428571428573),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(58),
#   'mean_error': np.float64(18.242857142857144),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(54),
#   'mean_error': np.float64(17.957142857142856),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(66),
#   'mean_error': np.float64(18.914285714285715),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(67),
#   'mean_error': np.float64(17.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(65),
#   'mean_error': np.float64(18.585714285714285),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(18.357142857142858),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(67),
#   'mean_error': np.float64(16.757142857142856),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(56),
#   'mean_error': np.float64(16.571428571428573),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(41),
#   'mean_error': np.float64(17.728571428571428),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(57),
#   'mean_error': np.float64(16.62857142857143),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(68),
#   'mean_error': np.float64(18.37142857142857),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(68),
#   'mean_error': np.float64(17.928571428571427),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(67),
#   'mean_error': np.float64(16.771428571428572),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(17.32857142857143),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(55),
#   'mean_error': np.float64(18.414285714285715),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(17.37142857142857),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(58),
#   'mean_error': np.float64(16.857142857142858),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(16.585714285714285),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(69),
#   'mean_error': np.float64(17.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
#   'max_error': np.int64(62),
#   'mean_error': np.float64(17.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_0.5_0.5',
#   'm': 70,
# ...
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(16.011111111111113),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(14.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(69),
#   'mean_error': np.float64(14.277777777777779),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(13.78888888888889),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(15.677777777777777),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(76),
#   'mean_error': np.float64(16.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(14.311111111111112),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(54),
#   'mean_error': np.float64(16.977777777777778),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(117),
#   'mean_error': np.float64(16.844444444444445),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(16.444444444444443),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(57),
#   'mean_error': np.float64(17.27777777777778),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(41),
#   'mean_error': np.float64(15.622222222222222),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(53),
#   'mean_error': np.float64(14.511111111111111),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(71),
#   'mean_error': np.float64(17.255555555555556),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(15.28888888888889),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(59),
#   'mean_error': np.float64(16.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(52),
#   'mean_error': np.float64(15.166666666666666),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(65),
#   'mean_error': np.float64(17.155555555555555),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_1_3',
#   'm': 90,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(15.588888888888889),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(17.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(17.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(17.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(18.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(26),
#   'mean_error': np.float64(11.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(13.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(57),
#   'mean_error': np.float64(20.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(15.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(15.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(14.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(13.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(14.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(11.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(12.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(12.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(17.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(15.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(10.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(12.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(16.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(17.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(73),
#   'mean_error': np.float64(20.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(15.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(13.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(52),
#   'mean_error': np.float64(18.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(11.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(12.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(27),
#   'mean_error': np.float64(9.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(12.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(18.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(23.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(13.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(15.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(14.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(23),
#   'mean_error': np.float64(9.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(11.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(13.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(16.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(25),
#   'mean_error': np.float64(12.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(15.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(15),
#   'mean_error': np.float64(6.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(16.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(15.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(14.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(15.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(14.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(14.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(19),
#   'mean_error': np.float64(13.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(15.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 10,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(17.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(18.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(14.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(31),
#   'mean_error': np.float64(14.15),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(58),
#   'mean_error': np.float64(18.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(21.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(14.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(50),
#   'mean_error': np.float64(16.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(16.8),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(17.15),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(41),
#   'mean_error': np.float64(16.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(16.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(14.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(16.45),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(15.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(24),
#   'mean_error': np.float64(14.25),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(12.55),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(17.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(17.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(13.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(52),
#   'mean_error': np.float64(18.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(17.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(47),
#   'mean_error': np.float64(15.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(17.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(35),
#   'mean_error': np.float64(15.2),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(60),
#   'mean_error': np.float64(18.15),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(39),
#   'mean_error': np.float64(19.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(51),
#   'mean_error': np.float64(17.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(28),
#   'mean_error': np.float64(13.3),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(32),
#   'mean_error': np.float64(13.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(15.1),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(40),
#   'mean_error': np.float64(15.85),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(14.45),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(46),
#   'mean_error': np.float64(15.75),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(15.85),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(19.6),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(36),
#   'mean_error': np.float64(17.0),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(14.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(44),
#   'mean_error': np.float64(14.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(63),
#   'mean_error': np.float64(18.5),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(30),
#   'mean_error': np.float64(15.35),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(38),
#   'mean_error': np.float64(15.15),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(34),
#   'mean_error': np.float64(14.75),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(15.85),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(43),
#   'mean_error': np.float64(20.45),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(12.4),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(42),
#   'mean_error': np.float64(13.65),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(49),
#   'mean_error': np.float64(16.9),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(33),
#   'mean_error': np.float64(13.95),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(48),
#   'mean_error': np.float64(17.7),
#   'Algorithm': 'SliceQuantile'},
#  {'dataset': 'Beta_2_2',
#   'm': 20,
#   'max_error': np.int64(37),
#   'mean_error': np.float64(16.55),
#   'Algorithm': 'SliceQuantile'},
#  ...]

# %% [markdown]
# # Plot the results

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="white")

DF = pd.DataFrame(records)
# save DF
DF.to_csv("../results/nice_distribution", index=False)

# %% [markdown]
# ## Max Error

# %%
# Create a grid of subplots
fig, axes = plt.subplots(2, 4, figsize=(20, 10), sharex=True, sharey=True)
axes = axes.flatten()

# Plot each dataset
for i, (key, data) in enumerate(DATASET.items()):
    ax = axes[i]
    df = DF[DF["dataset"] == key]
    sns.lineplot(
        data=df,
        x="m",
        y="max_error",
        hue="Algorithm",
        errorbar=('ci', 95),  # confidence interval 95%
        linewidth=2,
        ax=ax,
    )
    ax.set_title(key)
    ax.set_xlabel("Number of Quantiles (m)")
    ax.set_ylabel("Max Rank Error")
    ax.set_yscale("log")
    ax.legend().remove()  # Remove individual legends

# Remove unused subplots
if len(DATASET) < len(axes):
    for j in range(len(DATASET), len(axes)):
        fig.delaxes(axes[j])

# Add a single legend for the entire figure
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=len(labels), title="Algorithm")

# Adjust layout to fit the legend
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
# Create a grid of subplots
fig, axes = plt.subplots(2, 4, figsize=(20, 10), sharex=True, sharey=True)
axes = axes.flatten()

# Plot each dataset
for i, (key, data) in enumerate(DATASET.items()):
    ax = axes[i]
    df = DF[DF["dataset"] == key]
    sns.lineplot(
        data=df,
        x="m",
        y="mean_error",
        hue="Algorithm",
        errorbar=('ci', 95),  # confidence interval 95%
        linewidth=2,
        ax=ax,
    )
    ax.set_title(key)
    ax.set_xlabel("Number of Quantiles (m)")
    ax.set_ylabel("Mean Rank Error")
    ax.set_yscale("log")
    ax.legend().remove()  # Remove individual legends

# Remove unused subplots
if len(DATASET) < len(axes):
    for j in range(len(DATASET), len(axes)):
        fig.delaxes(axes[j])

# Add a single legend for the entire figure
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=len(labels), title="Algorithm")

# Adjust layout to fit the legend
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
